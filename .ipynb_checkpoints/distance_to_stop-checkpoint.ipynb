# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import geopandas as gpd
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
centroid = gpd.read_file("PLUTO/centroid_2.shp")
station = gpd.read_file("PLUTO/station.shp")
area_of_interest =  gpd.read_file("PLUTO/area_of_interest4.shp")
distance = pd.read_csv("PLUTO/distance7.csv",skipinitialspace=True)

# %%
centroid.head()
# Out:
#   Borough  Block  Lot   CD  CT2010 CB2010 SchoolDist  Council  ZipCode  \
# 0      MN   1378   14  108     122   3003         02        4    10065
# 1      MN   1375  147  108  114.01   1002         02        4    10065
# 2      MN   1378    6  108     122   3003         02        4    10065
# 3      MN   1378   12  108     122   3003         02        4    10065
# 4      MN   1377    9  108  114.01   2000         02        4    10065
#
#   FireComp                     ...                       EDesigNum  \
# 0     E039                     ...
# 1     E039                     ...
# 2     E039                     ...
# 3     E039                     ...
# 4     E039                     ...
#
#          APPBBL     APPDate PLUTOMapID Version MAPPLUTO_F  SHAPE_Leng  \
# 0  0.000000e+00                      1    16V2          0  192.749368
# 1  1.013750e+09  01/02/1988          1    16V2          0  245.754511
# 2  0.000000e+00                      1    16V2          0  257.678613
# 3  0.000000e+00                      1    16V2          0  258.647801
# 4  0.000000e+00                      1    16V2          0  256.914693
#
#     SHAPE_Area ORIG_FID                                     geometry
# 0  1636.104932        0  POINT (992629.7680759436 218454.7785905957)
# 1  2139.705254        1   POINT (992542.715136134 217773.6055392899)
# 2  2581.711429        2  POINT (992431.1791893283 218611.4974676166)
# 3  2632.094034        3  POINT (992558.5324777977 218541.0479910373)
# 4  2530.165935        4  POINT (992370.5664023436 218346.9121459293)
#
# [5 rows x 89 columns]

# %%
area_of_interest.head()
# Out:
#   Borough  Block  Lot   CD CT2010 CB2010 SchoolDist  Council  ZipCode  \
# 0      MN   1435   27  108    110   6003         02        5    10065
# 1      MN   1436  122  108    110   6000         02        5    10065
# 2      MN   1436    9  108    110   6001         02        5    10065
# 3      MN   1437  120  108    110   5000         02        5    10065
# 4      MN   1435  151  108    110   6002         02        5    10065
#
#   FireComp                        ...                          APPDate  \
# 0     L016                        ...
# 1     L016                        ...
# 2     L016                        ...
# 3     L016                        ...
# 4     L016                        ...
#
#    PLUTOMapID Version MAPPLUTO_F  SHAPE_Leng   SHAPE_Area FID_1    distance  \
# 0           1    16V2          0  236.659787  2314.891970   116  939.152656
# 1           1    16V2          0  352.253875  5497.290100   118  874.914146
# 2           1    16V2          0  256.000614  2787.212618   130  861.418762
# 3           1    16V2          0  239.032256  1737.573152   138  795.734089
# 4           1    16V2          0  196.045663  1549.534150   139  912.633273
#
#   east_or__1                                           geometry
# 0          1  POLYGON ((994945.5022000074 216411.7008000016,...
# 1          1  POLYGON ((995005.6993999928 216675.109799996, ...
# 2          1  POLYGON ((994679.4669999927 216827.0022000074,...
# 3          1  POLYGON ((995057.0594000071 216917.805399999, ...
# 4          1  POLYGON ((994446.7742000073 216705.2606000006,...
#
# [5 rows x 91 columns]

# %%
station.plot(marker='*', color='green', markersize=5);
station = station.to_crs(area_of_interest.crs)

# %%
fig = plt.figure(figsize=[10,13])
ax = fig.add_subplot(111)
ax.set_aspect('equal')
area_of_interest.plot(column='distance', cmap='Blues_r',ax=ax,alpha=1)
station.plot(ax=ax, marker='*', color='red', markersize=10)

# %%
fig = plt.figure(figsize=[10,13])
ax = fig.add_subplot(111)
ax.set_aspect('equal')
area_of_interest.plot(column='east_or__1', cmap='Accent',ax=ax,alpha=1)
station.plot(ax=ax, marker='*', color='red', markersize=10)

# %%
distance.head()
# Out:
#    FID     distance
# 0    0  1001.360647
# 1    1  1101.823443
# 2    2  1047.971649
# 3    3  1015.322174
# 4    4  1086.452827

# %%
print area_of_interest.columns
# Out:
# Index([   u'Borough',      u'Block',        u'Lot',         u'CD',
#            u'CT2010',     u'CB2010', u'SchoolDist',    u'Council',
#           u'ZipCode',   u'FireComp', u'PolicePrct', u'HealthArea',
#         u'SanitBoro', u'SanitDistr',   u'SanitSub',    u'Address',
#         u'ZoneDist1',  u'ZoneDist2',  u'ZoneDist3',  u'ZoneDist4',
#          u'Overlay1',   u'Overlay2',    u'SPDist1',    u'SPDist2',
#           u'SPDist3',  u'LtdHeight',  u'SplitZone',  u'BldgClass',
#           u'LandUse',  u'Easements',  u'OwnerType',  u'OwnerName',
#           u'LotArea',   u'BldgArea',    u'ComArea',    u'ResArea',
#        u'OfficeArea', u'RetailArea', u'GarageArea',  u'StrgeArea',
#        u'FactryArea',  u'OtherArea', u'AreaSource',   u'NumBldgs',
#         u'NumFloors',   u'UnitsRes', u'UnitsTotal',   u'LotFront',
#          u'LotDepth',  u'BldgFront',  u'BldgDepth',        u'Ext',
#          u'ProxCode', u'IrrLotCode',    u'LotType',   u'BsmtCode',
#        u'AssessLand',  u'AssessTot', u'ExemptLand',  u'ExemptTot',
#         u'YearBuilt', u'YearAlter1', u'YearAlter2',   u'HistDist',
#          u'Landmark',   u'BuiltFAR',   u'ResidFAR',    u'CommFAR',
#          u'FacilFAR',   u'BoroCode',        u'BBL',    u'CondoNo',
#         u'Tract2010',     u'XCoord',     u'YCoord',    u'ZoneMap',
#            u'ZMCode',    u'Sanborn',     u'TaxMap',  u'EDesigNum',
#            u'APPBBL',    u'APPDate', u'PLUTOMapID',    u'Version',
#        u'MAPPLUTO_F', u'SHAPE_Leng', u'SHAPE_Area',      u'FID_1',
#          u'distance', u'east_or__1',   u'geometry'],
#       dtype='object')

# %%
fig = plt.figure(figsize = [15,10])
ax = fig.add_subplot(111)

plt.scatter(area_of_interest[u'FID_1'],area_of_interest[u'distance'],c=area_of_interest[u'east_or__1'], s=10)
plt.xlabel('FID')
plt.ylabel('distance')
plt.legend()
plt.show()
