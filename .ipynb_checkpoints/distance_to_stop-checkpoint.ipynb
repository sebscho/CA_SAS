# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import geopandas as gpd
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
centroid = gpd.read_file("PLUTO/centroid_2.shp")
SAS = gpd.read_file("PLUTO/station.shp")
allstation = gpd.read_file("PLUTO/Subway Stations/geo_export_998f8b65-eced-46a1-b133-f1df2dde8997.shp")
area_of_interest =  gpd.read_file("PLUTO/area_of_interest5.shp")
distance = pd.read_csv("PLUTO/distance7.csv",skipinitialspace=True)

# %%
allstation.head()
# Out:
#                                                notes  \
# 0  4 nights, 6-all times, 6 Express-weekdays AM s...
# 1  4 nights, 6-all times, 6 Express-weekdays AM s...
# 2  4,6-all times, 5-all times exc nights, 6 Expre...
# 3  4 nights, 6-all times, 6 Express-weekdays AM s...
# 4                                      2,3-all times
#
#                                  url                           name  objectid  \
# 0  http://web.mta.info/nyct/service/                        96th St      33.0
# 1  http://web.mta.info/nyct/service/                        77th St      34.0
# 2  http://web.mta.info/nyct/service/        Lexington Ave - 59th St      49.0
# 3  http://web.mta.info/nyct/service/       68th St - Hunter College     102.0
# 4  http://web.mta.info/nyct/service/  Central Park North (110th St)     160.0
#
#               line                                     geometry
# 0    4-6-6 Express  POINT (997799.9148173952 225522.1638225947)
# ...

# %%
area_of_interest.head()
# Out:
#   Borough  Block  Lot   CD CT2010 CB2010 SchoolDist  Council  ZipCode  \
# 0      MN   1435   27  108    110   6003         02        5    10065
# 1      MN   1436  122  108    110   6000         02        5    10065
# 2      MN   1436    9  108    110   6001         02        5    10065
# 3      MN   1437  120  108    110   5000         02        5    10065
# 4      MN   1435  151  108    110   6002         02        5    10065
#
#   FireComp                        ...                          Version  \
# 0     L016                        ...                             16V2
# 1     L016                        ...                             16V2
# 2     L016                        ...                             16V2
# 3     L016                        ...                             16V2
# 4     L016                        ...                             16V2
#
#    MAPPLUTO_F  SHAPE_Leng   SHAPE_Area FID_1    distance east_or__1 FID_12  \
# ...

# %%
SAS.plot(marker='*', color='green', markersize=5);
SAS= SAS.to_crs(area_of_interest.crs)

# %%
fig = plt.figure(figsize=[10,13])
ax = fig.add_subplot(111)
ax.set_aspect('equal')
area_of_interest.plot(column='distance', cmap='Blues_r',ax=ax,alpha=1)
SAS.plot(ax=ax, marker='*', color='yellow', markersize=100)

# %%
allstation.plot(marker='*', color='green', markersize=5);
allstation= allstation.to_crs(area_of_interest.crs)

# %%
fig = plt.figure(figsize=[10,13])
ax = fig.add_subplot(111)
ax.set_aspect('equal')
area_of_interest.plot(column='distance', cmap='Blues_r',ax=ax,alpha=1)
allstation.plot(ax=ax, marker='*', color='red', markersize=10)

# %%
fig = plt.figure(figsize=[10,13])
ax = fig.add_subplot(111)
ax.set_aspect('equal')
area_of_interest.plot(column='east_or__1', cmap='Accent',ax=ax,alpha=1)
station.plot(ax=ax, marker='*', color='red', markersize=10)

# %%
distance.head()
# Out:
#    FID     distance
# 0    0  1001.360647
# 1    1  1101.823443
# 2    2  1047.971649
# 3    3  1015.322174
# 4    4  1086.452827

# %%
print area_of_interest.columns
# Out:
# Index([   u'Borough',      u'Block',        u'Lot',         u'CD',
#            u'CT2010',     u'CB2010', u'SchoolDist',    u'Council',
#           u'ZipCode',   u'FireComp', u'PolicePrct', u'HealthArea',
#         u'SanitBoro', u'SanitDistr',   u'SanitSub',    u'Address',
#         u'ZoneDist1',  u'ZoneDist2',  u'ZoneDist3',  u'ZoneDist4',
#          u'Overlay1',   u'Overlay2',    u'SPDist1',    u'SPDist2',
#           u'SPDist3',  u'LtdHeight',  u'SplitZone',  u'BldgClass',
#           u'LandUse',  u'Easements',  u'OwnerType',  u'OwnerName',
#           u'LotArea',   u'BldgArea',    u'ComArea',    u'ResArea',
#        u'OfficeArea', u'RetailArea', u'GarageArea',  u'StrgeArea',
#        u'FactryArea',  u'OtherArea', u'AreaSource',   u'NumBldgs',
#         u'NumFloors',   u'UnitsRes', u'UnitsTotal',   u'LotFront',
#          u'LotDepth',  u'BldgFront',  u'BldgDepth',        u'Ext',
#          u'ProxCode', u'IrrLotCode',    u'LotType',   u'BsmtCode',
# ...

# %%
fig = plt.figure(figsize = [15,10])
ax = fig.add_subplot(111)

plt.scatter(area_of_interest[u'FID_1'],area_of_interest[u'distance'],c=area_of_interest[u'east_or__1'], s=10)
plt.xlabel('FID')
plt.ylabel('distance')
plt.legend()
plt.show()
